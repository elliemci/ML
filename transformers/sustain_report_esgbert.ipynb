# %% [markdown]
# # Notebook Tasks

# %% [markdown]
# 1. Create a tokenizer and Initialize a model with the __PATH__ `nbroad/ESG-BERT`.
# 2. Use the TextClassificationPipeline from Huggingface.
# 3. Access the first row of the element of the dataframe and initialize the pipeline for the model.
# 4. Utilize `Pandas` function `idxmax()`.

# %% [markdown]
# # Imports

# %%
import pandas as pd

from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline

#ignore warnings
import warnings 
warnings.filterwarnings('ignore')
# Out:
# 2024-03-01 16:05:32.074195: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Data Path

# %%
PATH = 'data/'
FILENAME = 'report_data.csv'

# %% [markdown]
# ## Load the Data

# %%
# we load our extracted data from the previuos milestone
text = pd.read_csv(PATH + FILENAME)
text.head()
# Out:
#                                                 text
# 0  We believe that well-designed products have lo...
# 1  Our energy efficiency goals extend well beyond...
# 2  Last year, one of our manufacturers in Guangzh...
# 3  We’re at a pivotal moment in addressing climat...
# 4  Our goal to reach carbon neutrality by 2030 re...

# %% [markdown]
# ## Load the model from Huggingface

# %% [markdown]
# 1. Create a `tokenizer` with `AutoTokenizer.from_pretrained` [link to documentation](https://huggingface.co/docs/transformers/v4.21.1/en/model_doc/auto#transformers.AutoTokenizer.from_pretrained) and use the following __PATH__ : `'nbroad/ESG-BERT'`.
# 2. Initialize the `model` from `AutoModelForSequenceClassification.from_pretrained` with the __PATH__ : `'nbroad/ESG-BERT'`.

# %%
tokenizer = AutoTokenizer.from_pretrained("nbroad/ESG-BERT")

model = AutoModelForSequenceClassification.from_pretrained("nbroad/ESG-BERT")

# %% [markdown]
# ### Infos about the model's tokenizer

# %%
# get info about the tokenizer
print(tokenizer.is_fast)
print()
print(tokenizer)
# Out:
# True
#
# BertTokenizerFast(name_or_path='nbroad/ESG-BERT', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %% [markdown]
# Use the `TextClassificationPipeline` from Huggingface here is the link to the [documentation](https://huggingface.co/docs/transformers/v4.21.1/en/main_classes/pipelines#transformers.TextClassificationPipeline).

# %%
# initialize the pipeline for the text classification
pipe = TextClassificationPipeline(model=model, tokenizer=tokenizer, return_all_scores=True)

# %% [markdown]
# Access the first row of the element of the dataframe and initialize the `pipe()` with it i. e. `pipe(df.first_row)`.

# %%
test = pipe(text['text'][0])
test
# Out:
# [[{'label': 'Business_Ethics', 'score': 0.0005536633543670177},
#   {'label': 'Data_Security', 'score': 0.0005997914122417569},
#   {'label': 'Access_And_Affordability', 'score': 0.0010173521004617214},
#   {'label': 'Business_Model_Resilience', 'score': 0.002356546698138118},
#   {'label': 'Competitive_Behavior', 'score': 0.0005852491594851017},
#   {'label': 'Critical_Incident_Risk_Management',
#    'score': 0.0008547173929400742},
#   {'label': 'Customer_Welfare', 'score': 0.002451641019433737},
#   {'label': 'Director_Removal', 'score': 0.001316296518780291},
#   {'label': 'Employee_Engagement_Inclusion_And_Diversity',
#    'score': 0.0008579465211369097},
#   {'label': 'Employee_Health_And_Safety', 'score': 0.001422567875124514},
#   {'label': 'Human_Rights_And_Community_Relations',
#    'score': 0.0006334123318083584},
#   {'label': 'Labor_Practices', 'score': 0.0004994926857762039},
#   {'label': 'Management_Of_Legal_And_Regulatory_Framework',
#    'score': 0.0011158727575093508},
#   {'label': 'Physical_Impacts_Of_Climate_Change',
#    'score': 0.0008010580786503851},
#   {'label': 'Product_Quality_And_Safety', 'score': 0.0035566387232393026},
#   {'label': 'Product_Design_And_Lifecycle_Management',
#    'score': 0.9679327011108398},
#   {'label': 'Selling_Practices_And_Product_Labeling',
#    'score': 0.0021153632551431656},
#   {'label': 'Supply_Chain_Management', 'score': 0.0017227246426045895},
#   {'label': 'Systemic_Risk_Management', 'score': 0.0004053477314300835},
#   {'label': 'Waste_And_Hazardous_Materials_Management',
#    'score': 0.0013510392745956779},
#   {'label': 'Water_And_Wastewater_Management', 'score': 0.0009978878078982234},
#   {'label': 'Air_Quality', 'score': 0.0006271072197705507},
#   {'label': 'Customer_Privacy', 'score': 0.0016203528502956033},
#   {'label': 'Ecological_Impacts', 'score': 0.001872702850960195},
#   {'label': 'Energy_Management', 'score': 0.002101109130308032},
#   {'label': 'GHG_Emissions', 'score': 0.0006313714548014104}]]

# %% [markdown]
# `Pandas` function `idxmax()` with documentation [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html). This function is used to find the maximum value in each dataframe for the print-out.

# %%
# iterate  over the rows of the text dataframe applying the pipeline to each row wich returns a list of lists
for i in range(text.shape[0]):
    # flatten the list of lists into a single list and  storee it in result than  convert it to a dataframe
    result = sum(pipe(text.text[i]), [])
    df = pd.DataFrame(result)
    print(df)
    print()

    # find the label of the max score
    max_index = df.idxmax(numeric_only=True)[0]
    max_label = df.iloc[max_index][0]
    max_score = df.loc[max_index][1]

    #print(f"index of max score: {max_index}")
    #print(f"label of max score: {max_label}")
    #print(f"max score: {max_score}")

    print('\n dataframe {}'.format(i))
    print(df)
    print('\n',39 * '--')
    print(f'Max value from classification: label {max_label} with score {round(max_score, 4)}')
    print(40 *'==')
# Out:
#                                            label     score
# 0                                Business_Ethics  0.000554
# 1                                  Data_Security  0.000600
# 2                       Access_And_Affordability  0.001017
# 3                      Business_Model_Resilience  0.002357
# 4                           Competitive_Behavior  0.000585
# 5              Critical_Incident_Risk_Management  0.000855
# 6                               Customer_Welfare  0.002452
# 7                               Director_Removal  0.001316
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000858
# 9                     Employee_Health_And_Safety  0.001423
# 10          Human_Rights_And_Community_Relations  0.000633
# 11                               Labor_Practices  0.000499
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001116
# 13            Physical_Impacts_Of_Climate_Change  0.000801
# 14                    Product_Quality_And_Safety  0.003557
# 15       Product_Design_And_Lifecycle_Management  0.967933
# 16        Selling_Practices_And_Product_Labeling  0.002115
# 17                       Supply_Chain_Management  0.001723
# 18                      Systemic_Risk_Management  0.000405
# 19      Waste_And_Hazardous_Materials_Management  0.001351
# 20               Water_And_Wastewater_Management  0.000998
# 21                                   Air_Quality  0.000627
# 22                              Customer_Privacy  0.001620
# 23                            Ecological_Impacts  0.001873
# 24                             Energy_Management  0.002101
# 25                                 GHG_Emissions  0.000631
#
#
#  dataframe 0
#                                            label     score
# 0                                Business_Ethics  0.000554
# 1                                  Data_Security  0.000600
# 2                       Access_And_Affordability  0.001017
# 3                      Business_Model_Resilience  0.002357
# 4                           Competitive_Behavior  0.000585
# 5              Critical_Incident_Risk_Management  0.000855
# 6                               Customer_Welfare  0.002452
# 7                               Director_Removal  0.001316
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000858
# 9                     Employee_Health_And_Safety  0.001423
# 10          Human_Rights_And_Community_Relations  0.000633
# 11                               Labor_Practices  0.000499
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001116
# 13            Physical_Impacts_Of_Climate_Change  0.000801
# 14                    Product_Quality_And_Safety  0.003557
# 15       Product_Design_And_Lifecycle_Management  0.967933
# 16        Selling_Practices_And_Product_Labeling  0.002115
# 17                       Supply_Chain_Management  0.001723
# 18                      Systemic_Risk_Management  0.000405
# 19      Waste_And_Hazardous_Materials_Management  0.001351
# 20               Water_And_Wastewater_Management  0.000998
# 21                                   Air_Quality  0.000627
# 22                              Customer_Privacy  0.001620
# 23                            Ecological_Impacts  0.001873
# 24                             Energy_Management  0.002101
# 25                                 GHG_Emissions  0.000631
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Product_Design_And_Lifecycle_Management with score 0.9679
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.000712
# 1                                  Data_Security  0.001700
# 2                       Access_And_Affordability  0.004532
# 3                      Business_Model_Resilience  0.001112
# 4                           Competitive_Behavior  0.001661
# 5              Critical_Incident_Risk_Management  0.002852
# 6                               Customer_Welfare  0.003915
# 7                               Director_Removal  0.001724
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001209
# 9                     Employee_Health_And_Safety  0.001626
# 10          Human_Rights_And_Community_Relations  0.001661
# 11                               Labor_Practices  0.001515
# 12  Management_Of_Legal_And_Regulatory_Framework  0.003449
# 13            Physical_Impacts_Of_Climate_Change  0.002001
# 14                    Product_Quality_And_Safety  0.005091
# 15       Product_Design_And_Lifecycle_Management  0.070480
# 16        Selling_Practices_And_Product_Labeling  0.002846
# 17                       Supply_Chain_Management  0.005479
# 18                      Systemic_Risk_Management  0.000669
# 19      Waste_And_Hazardous_Materials_Management  0.002797
# 20               Water_And_Wastewater_Management  0.003550
# 21                                   Air_Quality  0.003366
# 22                              Customer_Privacy  0.001639
# 23                            Ecological_Impacts  0.001239
# 24                             Energy_Management  0.870809
# 25                                 GHG_Emissions  0.002367
#
#
#  dataframe 1
#                                            label     score
# 0                                Business_Ethics  0.000712
# 1                                  Data_Security  0.001700
# 2                       Access_And_Affordability  0.004532
# 3                      Business_Model_Resilience  0.001112
# 4                           Competitive_Behavior  0.001661
# 5              Critical_Incident_Risk_Management  0.002852
# 6                               Customer_Welfare  0.003915
# 7                               Director_Removal  0.001724
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001209
# 9                     Employee_Health_And_Safety  0.001626
# 10          Human_Rights_And_Community_Relations  0.001661
# 11                               Labor_Practices  0.001515
# 12  Management_Of_Legal_And_Regulatory_Framework  0.003449
# 13            Physical_Impacts_Of_Climate_Change  0.002001
# 14                    Product_Quality_And_Safety  0.005091
# 15       Product_Design_And_Lifecycle_Management  0.070480
# 16        Selling_Practices_And_Product_Labeling  0.002846
# 17                       Supply_Chain_Management  0.005479
# 18                      Systemic_Risk_Management  0.000669
# 19      Waste_And_Hazardous_Materials_Management  0.002797
# 20               Water_And_Wastewater_Management  0.003550
# 21                                   Air_Quality  0.003366
# 22                              Customer_Privacy  0.001639
# 23                            Ecological_Impacts  0.001239
# 24                             Energy_Management  0.870809
# 25                                 GHG_Emissions  0.002367
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Energy_Management with score 0.8708
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.001096
# 1                                  Data_Security  0.002704
# 2                       Access_And_Affordability  0.003071
# 3                      Business_Model_Resilience  0.001400
# 4                           Competitive_Behavior  0.001793
# 5              Critical_Incident_Risk_Management  0.010286
# 6                               Customer_Welfare  0.001578
# 7                               Director_Removal  0.002000
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000872
# 9                     Employee_Health_And_Safety  0.001824
# 10          Human_Rights_And_Community_Relations  0.001456
# 11                               Labor_Practices  0.003461
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001890
# 13            Physical_Impacts_Of_Climate_Change  0.003511
# 14                    Product_Quality_And_Safety  0.002709
# 15       Product_Design_And_Lifecycle_Management  0.003000
# 16        Selling_Practices_And_Product_Labeling  0.001459
# 17                       Supply_Chain_Management  0.002116
# 18                      Systemic_Risk_Management  0.002122
# 19      Waste_And_Hazardous_Materials_Management  0.003678
# 20               Water_And_Wastewater_Management  0.004718
# 21                                   Air_Quality  0.881462
# 22                              Customer_Privacy  0.002314
# 23                            Ecological_Impacts  0.001076
# 24                             Energy_Management  0.055979
# 25                                 GHG_Emissions  0.002426
#
#
#  dataframe 2
#                                            label     score
# 0                                Business_Ethics  0.001096
# 1                                  Data_Security  0.002704
# 2                       Access_And_Affordability  0.003071
# 3                      Business_Model_Resilience  0.001400
# 4                           Competitive_Behavior  0.001793
# 5              Critical_Incident_Risk_Management  0.010286
# 6                               Customer_Welfare  0.001578
# 7                               Director_Removal  0.002000
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000872
# 9                     Employee_Health_And_Safety  0.001824
# 10          Human_Rights_And_Community_Relations  0.001456
# 11                               Labor_Practices  0.003461
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001890
# 13            Physical_Impacts_Of_Climate_Change  0.003511
# 14                    Product_Quality_And_Safety  0.002709
# 15       Product_Design_And_Lifecycle_Management  0.003000
# 16        Selling_Practices_And_Product_Labeling  0.001459
# 17                       Supply_Chain_Management  0.002116
# 18                      Systemic_Risk_Management  0.002122
# 19      Waste_And_Hazardous_Materials_Management  0.003678
# 20               Water_And_Wastewater_Management  0.004718
# 21                                   Air_Quality  0.881462
# 22                              Customer_Privacy  0.002314
# 23                            Ecological_Impacts  0.001076
# 24                             Energy_Management  0.055979
# 25                                 GHG_Emissions  0.002426
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Air_Quality with score 0.8815
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.000758
# 1                                  Data_Security  0.001962
# 2                       Access_And_Affordability  0.000827
# 3                      Business_Model_Resilience  0.009901
# 4                           Competitive_Behavior  0.000486
# 5              Critical_Incident_Risk_Management  0.002175
# 6                               Customer_Welfare  0.000816
# 7                               Director_Removal  0.002263
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001017
# 9                     Employee_Health_And_Safety  0.000926
# 10          Human_Rights_And_Community_Relations  0.002342
# 11                               Labor_Practices  0.000985
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001985
# 13            Physical_Impacts_Of_Climate_Change  0.943620
# 14                    Product_Quality_And_Safety  0.000788
# 15       Product_Design_And_Lifecycle_Management  0.001135
# 16        Selling_Practices_And_Product_Labeling  0.001116
# 17                       Supply_Chain_Management  0.005046
# 18                      Systemic_Risk_Management  0.003654
# 19      Waste_And_Hazardous_Materials_Management  0.000623
# 20               Water_And_Wastewater_Management  0.001278
# 21                                   Air_Quality  0.003238
# 22                              Customer_Privacy  0.001544
# 23                            Ecological_Impacts  0.002167
# 24                             Energy_Management  0.002252
# 25                                 GHG_Emissions  0.007096
#
#
#  dataframe 3
#                                            label     score
# 0                                Business_Ethics  0.000758
# 1                                  Data_Security  0.001962
# 2                       Access_And_Affordability  0.000827
# 3                      Business_Model_Resilience  0.009901
# 4                           Competitive_Behavior  0.000486
# 5              Critical_Incident_Risk_Management  0.002175
# 6                               Customer_Welfare  0.000816
# 7                               Director_Removal  0.002263
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001017
# 9                     Employee_Health_And_Safety  0.000926
# 10          Human_Rights_And_Community_Relations  0.002342
# 11                               Labor_Practices  0.000985
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001985
# 13            Physical_Impacts_Of_Climate_Change  0.943620
# 14                    Product_Quality_And_Safety  0.000788
# 15       Product_Design_And_Lifecycle_Management  0.001135
# 16        Selling_Practices_And_Product_Labeling  0.001116
# 17                       Supply_Chain_Management  0.005046
# 18                      Systemic_Risk_Management  0.003654
# 19      Waste_And_Hazardous_Materials_Management  0.000623
# 20               Water_And_Wastewater_Management  0.001278
# 21                                   Air_Quality  0.003238
# 22                              Customer_Privacy  0.001544
# 23                            Ecological_Impacts  0.002167
# 24                             Energy_Management  0.002252
# 25                                 GHG_Emissions  0.007096
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Physical_Impacts_Of_Climate_Change with score 0.9436
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.001347
# 1                                  Data_Security  0.000678
# 2                       Access_And_Affordability  0.002232
# 3                      Business_Model_Resilience  0.002547
# 4                           Competitive_Behavior  0.001117
# 5              Critical_Incident_Risk_Management  0.001324
# 6                               Customer_Welfare  0.002131
# 7                               Director_Removal  0.001770
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000844
# 9                     Employee_Health_And_Safety  0.000723
# 10          Human_Rights_And_Community_Relations  0.003306
# 11                               Labor_Practices  0.002176
# 12  Management_Of_Legal_And_Regulatory_Framework  0.007474
# 13            Physical_Impacts_Of_Climate_Change  0.004911
# 14                    Product_Quality_And_Safety  0.001552
# 15       Product_Design_And_Lifecycle_Management  0.001932
# 16        Selling_Practices_And_Product_Labeling  0.001865
# 17                       Supply_Chain_Management  0.001129
# 18                      Systemic_Risk_Management  0.001083
# 19      Waste_And_Hazardous_Materials_Management  0.001319
# 20               Water_And_Wastewater_Management  0.003106
# 21                                   Air_Quality  0.067555
# 22                              Customer_Privacy  0.001583
# 23                            Ecological_Impacts  0.004660
# 24                             Energy_Management  0.008008
# 25                                 GHG_Emissions  0.873628
#
#
#  dataframe 4
#                                            label     score
# 0                                Business_Ethics  0.001347
# 1                                  Data_Security  0.000678
# 2                       Access_And_Affordability  0.002232
# 3                      Business_Model_Resilience  0.002547
# 4                           Competitive_Behavior  0.001117
# 5              Critical_Incident_Risk_Management  0.001324
# 6                               Customer_Welfare  0.002131
# 7                               Director_Removal  0.001770
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000844
# 9                     Employee_Health_And_Safety  0.000723
# 10          Human_Rights_And_Community_Relations  0.003306
# 11                               Labor_Practices  0.002176
# 12  Management_Of_Legal_And_Regulatory_Framework  0.007474
# 13            Physical_Impacts_Of_Climate_Change  0.004911
# 14                    Product_Quality_And_Safety  0.001552
# 15       Product_Design_And_Lifecycle_Management  0.001932
# 16        Selling_Practices_And_Product_Labeling  0.001865
# 17                       Supply_Chain_Management  0.001129
# 18                      Systemic_Risk_Management  0.001083
# 19      Waste_And_Hazardous_Materials_Management  0.001319
# 20               Water_And_Wastewater_Management  0.003106
# 21                                   Air_Quality  0.067555
# 22                              Customer_Privacy  0.001583
# 23                            Ecological_Impacts  0.004660
# 24                             Energy_Management  0.008008
# 25                                 GHG_Emissions  0.873628
#
#  ------------------------------------------------------------------------------
# Max value from classification: label GHG_Emissions with score 0.8736
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.001496
# 1                                  Data_Security  0.000751
# 2                       Access_And_Affordability  0.001556
# 3                      Business_Model_Resilience  0.001960
# 4                           Competitive_Behavior  0.001111
# 5              Critical_Incident_Risk_Management  0.000502
# 6                               Customer_Welfare  0.001926
# 7                               Director_Removal  0.001001
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001118
# 9                     Employee_Health_And_Safety  0.001188
# 10          Human_Rights_And_Community_Relations  0.005524
# 11                               Labor_Practices  0.000567
# 12  Management_Of_Legal_And_Regulatory_Framework  0.002919
# 13            Physical_Impacts_Of_Climate_Change  0.001249
# 14                    Product_Quality_And_Safety  0.001048
# 15       Product_Design_And_Lifecycle_Management  0.002262
# 16        Selling_Practices_And_Product_Labeling  0.001318
# 17                       Supply_Chain_Management  0.002070
# 18                      Systemic_Risk_Management  0.001272
# 19      Waste_And_Hazardous_Materials_Management  0.001383
# 20               Water_And_Wastewater_Management  0.002561
# 21                                   Air_Quality  0.000614
# 22                              Customer_Privacy  0.000644
# 23                            Ecological_Impacts  0.959584
# 24                             Energy_Management  0.000519
# 25                                 GHG_Emissions  0.003858
#
#
#  dataframe 5
#                                            label     score
# 0                                Business_Ethics  0.001496
# 1                                  Data_Security  0.000751
# 2                       Access_And_Affordability  0.001556
# 3                      Business_Model_Resilience  0.001960
# 4                           Competitive_Behavior  0.001111
# 5              Critical_Incident_Risk_Management  0.000502
# 6                               Customer_Welfare  0.001926
# 7                               Director_Removal  0.001001
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001118
# 9                     Employee_Health_And_Safety  0.001188
# 10          Human_Rights_And_Community_Relations  0.005524
# 11                               Labor_Practices  0.000567
# 12  Management_Of_Legal_And_Regulatory_Framework  0.002919
# 13            Physical_Impacts_Of_Climate_Change  0.001249
# 14                    Product_Quality_And_Safety  0.001048
# 15       Product_Design_And_Lifecycle_Management  0.002262
# 16        Selling_Practices_And_Product_Labeling  0.001318
# 17                       Supply_Chain_Management  0.002070
# 18                      Systemic_Risk_Management  0.001272
# 19      Waste_And_Hazardous_Materials_Management  0.001383
# 20               Water_And_Wastewater_Management  0.002561
# 21                                   Air_Quality  0.000614
# 22                              Customer_Privacy  0.000644
# 23                            Ecological_Impacts  0.959584
# 24                             Energy_Management  0.000519
# 25                                 GHG_Emissions  0.003858
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Ecological_Impacts with score 0.9596
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.000684
# 1                                  Data_Security  0.000972
# 2                       Access_And_Affordability  0.000819
# 3                      Business_Model_Resilience  0.002052
# 4                           Competitive_Behavior  0.000444
# 5              Critical_Incident_Risk_Management  0.000831
# 6                               Customer_Welfare  0.002025
# 7                               Director_Removal  0.002052
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001062
# 9                     Employee_Health_And_Safety  0.001927
# 10          Human_Rights_And_Community_Relations  0.000667
# 11                               Labor_Practices  0.000614
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001276
# 13            Physical_Impacts_Of_Climate_Change  0.000895
# 14                    Product_Quality_And_Safety  0.003067
# 15       Product_Design_And_Lifecycle_Management  0.964612
# 16        Selling_Practices_And_Product_Labeling  0.002892
# 17                       Supply_Chain_Management  0.002019
# 18                      Systemic_Risk_Management  0.000392
# 19      Waste_And_Hazardous_Materials_Management  0.002355
# 20               Water_And_Wastewater_Management  0.001009
# 21                                   Air_Quality  0.000596
# 22                              Customer_Privacy  0.002300
# 23                            Ecological_Impacts  0.001969
# 24                             Energy_Management  0.001939
# 25                                 GHG_Emissions  0.000532
#
#
#  dataframe 6
#                                            label     score
# 0                                Business_Ethics  0.000684
# 1                                  Data_Security  0.000972
# 2                       Access_And_Affordability  0.000819
# 3                      Business_Model_Resilience  0.002052
# 4                           Competitive_Behavior  0.000444
# 5              Critical_Incident_Risk_Management  0.000831
# 6                               Customer_Welfare  0.002025
# 7                               Director_Removal  0.002052
# 8    Employee_Engagement_Inclusion_And_Diversity  0.001062
# 9                     Employee_Health_And_Safety  0.001927
# 10          Human_Rights_And_Community_Relations  0.000667
# 11                               Labor_Practices  0.000614
# 12  Management_Of_Legal_And_Regulatory_Framework  0.001276
# 13            Physical_Impacts_Of_Climate_Change  0.000895
# 14                    Product_Quality_And_Safety  0.003067
# 15       Product_Design_And_Lifecycle_Management  0.964612
# 16        Selling_Practices_And_Product_Labeling  0.002892
# 17                       Supply_Chain_Management  0.002019
# 18                      Systemic_Risk_Management  0.000392
# 19      Waste_And_Hazardous_Materials_Management  0.002355
# 20               Water_And_Wastewater_Management  0.001009
# 21                                   Air_Quality  0.000596
# 22                              Customer_Privacy  0.002300
# 23                            Ecological_Impacts  0.001969
# 24                             Energy_Management  0.001939
# 25                                 GHG_Emissions  0.000532
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Product_Design_And_Lifecycle_Management with score 0.9646
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.000366
# 1                                  Data_Security  0.001273
# 2                       Access_And_Affordability  0.000606
# 3                      Business_Model_Resilience  0.000285
# 4                           Competitive_Behavior  0.000301
# 5              Critical_Incident_Risk_Management  0.000409
# 6                               Customer_Welfare  0.000738
# 7                               Director_Removal  0.000807
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000902
# 9                     Employee_Health_And_Safety  0.000968
# 10          Human_Rights_And_Community_Relations  0.000177
# 11                               Labor_Practices  0.000917
# 12  Management_Of_Legal_And_Regulatory_Framework  0.000579
# 13            Physical_Impacts_Of_Climate_Change  0.000585
# 14                    Product_Quality_And_Safety  0.000826
# 15       Product_Design_And_Lifecycle_Management  0.001876
# 16        Selling_Practices_And_Product_Labeling  0.000780
# 17                       Supply_Chain_Management  0.001058
# 18                      Systemic_Risk_Management  0.000394
# 19      Waste_And_Hazardous_Materials_Management  0.979648
# 20               Water_And_Wastewater_Management  0.001924
# 21                                   Air_Quality  0.001508
# 22                              Customer_Privacy  0.000967
# 23                            Ecological_Impacts  0.000936
# 24                             Energy_Management  0.000836
# 25                                 GHG_Emissions  0.000333
#
#
#  dataframe 7
#                                            label     score
# 0                                Business_Ethics  0.000366
# 1                                  Data_Security  0.001273
# 2                       Access_And_Affordability  0.000606
# 3                      Business_Model_Resilience  0.000285
# 4                           Competitive_Behavior  0.000301
# 5              Critical_Incident_Risk_Management  0.000409
# 6                               Customer_Welfare  0.000738
# 7                               Director_Removal  0.000807
# 8    Employee_Engagement_Inclusion_And_Diversity  0.000902
# 9                     Employee_Health_And_Safety  0.000968
# 10          Human_Rights_And_Community_Relations  0.000177
# 11                               Labor_Practices  0.000917
# 12  Management_Of_Legal_And_Regulatory_Framework  0.000579
# 13            Physical_Impacts_Of_Climate_Change  0.000585
# 14                    Product_Quality_And_Safety  0.000826
# 15       Product_Design_And_Lifecycle_Management  0.001876
# 16        Selling_Practices_And_Product_Labeling  0.000780
# 17                       Supply_Chain_Management  0.001058
# 18                      Systemic_Risk_Management  0.000394
# 19      Waste_And_Hazardous_Materials_Management  0.979648
# 20               Water_And_Wastewater_Management  0.001924
# 21                                   Air_Quality  0.001508
# 22                              Customer_Privacy  0.000967
# 23                            Ecological_Impacts  0.000936
# 24                             Energy_Management  0.000836
# 25                                 GHG_Emissions  0.000333
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Waste_And_Hazardous_Materials_Management with score 0.9796
# ================================================================================
#                                            label     score
# 0                                Business_Ethics  0.012380
# 1                                  Data_Security  0.009946
# 2                       Access_And_Affordability  0.017480
# 3                      Business_Model_Resilience  0.251664
# 4                           Competitive_Behavior  0.023182
# 5              Critical_Incident_Risk_Management  0.008652
# 6                               Customer_Welfare  0.040204
# 7                               Director_Removal  0.009423
# 8    Employee_Engagement_Inclusion_And_Diversity  0.055909
# 9                     Employee_Health_And_Safety  0.025623
# 10          Human_Rights_And_Community_Relations  0.018019
# 11                               Labor_Practices  0.006073
# 12  Management_Of_Legal_And_Regulatory_Framework  0.005065
# 13            Physical_Impacts_Of_Climate_Change  0.007830
# 14                    Product_Quality_And_Safety  0.011018
# 15       Product_Design_And_Lifecycle_Management  0.337821
# 16        Selling_Practices_And_Product_Labeling  0.009711
# 17                       Supply_Chain_Management  0.027669
# 18                      Systemic_Risk_Management  0.018466
# 19      Waste_And_Hazardous_Materials_Management  0.017436
# 20               Water_And_Wastewater_Management  0.015377
# 21                                   Air_Quality  0.007601
# 22                              Customer_Privacy  0.016189
# 23                            Ecological_Impacts  0.027598
# 24                             Energy_Management  0.014913
# 25                                 GHG_Emissions  0.004753
#
#
#  dataframe 8
#                                            label     score
# 0                                Business_Ethics  0.012380
# 1                                  Data_Security  0.009946
# 2                       Access_And_Affordability  0.017480
# 3                      Business_Model_Resilience  0.251664
# 4                           Competitive_Behavior  0.023182
# 5              Critical_Incident_Risk_Management  0.008652
# 6                               Customer_Welfare  0.040204
# 7                               Director_Removal  0.009423
# 8    Employee_Engagement_Inclusion_And_Diversity  0.055909
# 9                     Employee_Health_And_Safety  0.025623
# 10          Human_Rights_And_Community_Relations  0.018019
# 11                               Labor_Practices  0.006073
# 12  Management_Of_Legal_And_Regulatory_Framework  0.005065
# 13            Physical_Impacts_Of_Climate_Change  0.007830
# 14                    Product_Quality_And_Safety  0.011018
# 15       Product_Design_And_Lifecycle_Management  0.337821
# 16        Selling_Practices_And_Product_Labeling  0.009711
# 17                       Supply_Chain_Management  0.027669
# 18                      Systemic_Risk_Management  0.018466
# 19      Waste_And_Hazardous_Materials_Management  0.017436
# 20               Water_And_Wastewater_Management  0.015377
# 21                                   Air_Quality  0.007601
# 22                              Customer_Privacy  0.016189
# 23                            Ecological_Impacts  0.027598
# 24                             Energy_Management  0.014913
# 25                                 GHG_Emissions  0.004753
#
#  ------------------------------------------------------------------------------
# Max value from classification: label Product_Design_And_Lifecycle_Management with score 0.3378
# ================================================================================
